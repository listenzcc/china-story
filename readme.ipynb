# %%
import jieba
import pinyin
import requests
import traceback
import pandas as pd

from pathlib import Path
from tqdm.auto import tqdm
from bs4 import BeautifulSoup as bs

# %%
content_folder = Path('./content')
content_folder.mkdir(exist_ok=True)


def get_name_by_url(url):
    '''
    Get name from $url

    :param: url: input url

    :return: the name parsed from url
    '''
    return url.split('/')[-1]


def content_from_url(url, override=False):
    '''
    Get content from $url.
    It checks content_folder first,
    if not found, it requests the content and saves.
    
    :param: url: input url
    :param: override: whether to overwrite existing contents, default is False

    :return: content: the content being requested from url
    '''
    name = get_name_by_url(url)
    p = content_folder.joinpath(name)

    if not p.is_file() or override:
        resp = requests.get(url)
        content = resp.content
        with open(p, 'wb') as f:
            f.write(content)
    else:
        content = open(p, 'rb').read()

    return content

# %%
url = 'http://www.gov.cn/guoqing/2009-10/09/content_2582666.htm'

content = content_from_url(url)

soup = bs(content)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
lst = []

_table = soup.find('table')
for td in tqdm(_table.find_all('td'), 'Search table'):
    try:
        text = td.text
        href = td.find('a').attrs['href']
        lst.append(dict(
            year=text.strip().replace(' ', ''),
            url=href
        ))
    except AttributeError:
        traceback.print_exc()
        continue

df = pd.DataFrame(lst)
df['name'] = df['url'].map(get_name_by_url)
raw_table = df
raw_table
# Out:
# Search table:   0%|          | 0/63 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "C:\Users\zcc\AppData\Local\Temp\ipykernel_26108\2796673242.py", line 7, in <module>
#     href = td.find('a').attrs['href']
# AttributeError: 'NoneType' object has no attribute 'attrs'
# Traceback (most recent call last):
#   File "C:\Users\zcc\AppData\Local\Temp\ipykernel_26108\2796673242.py", line 7, in <module>
#     href = td.find('a').attrs['href']
# AttributeError: 'NoneType' object has no attribute 'attrs'
# Traceback (most recent call last):
#   File "C:\Users\zcc\AppData\Local\Temp\ipykernel_26108\2796673242.py", line 7, in <module>
#     href = td.find('a').attrs['href']
# AttributeError: 'NoneType' object has no attribute 'attrs'
#     year                                                url  \
# 0   1949  http://www.gov.cn/test/2009-10/09/content_1434...
# 1   1950  http://www.gov.cn/test/2009-10/09/content_1434...
# 2   1951  http://www.gov.cn/test/2009-10/09/content_1434...
# 3   1952  http://www.gov.cn/test/2009-10/09/content_1434...
# 4   1953  http://www.gov.cn/test/2009-10/09/content_1434...
# 5   1954  http://www.gov.cn/test/2009-10/09/content_1434...
# 6   1955  http://www.gov.cn/test/2009-10/09/content_1434...
# 7   1956  http://www.gov.cn/test/2009-10/09/content_1434...
# 8   1957  http://www.gov.cn/test/2009-10/09/content_1434...
# 9   1958  http://www.gov.cn/test/2009-10/09/content_1434...
# 10  1959  http://www.gov.cn/test/2009-10/09/content_1434...
# 11  1960  http://www.gov.cn/test/2009-10/09/content_1434...
# 12  1961  http://www.gov.cn/test/2009-10/09/content_1434...
# 13  1962  http://www.gov.cn/test/2009-10/09/content_1434...
# 14  1963  http://www.gov.cn/test/2009-10/09/content_1434...
# 15  1964  http://www.gov.cn/test/2009-10/09/content_1434...
# 16  1965  http://www.gov.cn/test/2009-10/09/content_1434...
# 17  1966  http://www.gov.cn/test/2009-10/09/content_1434...
# 18  1967  http://www.gov.cn/test/2009-10/09/content_1434...
# 19  1968  http://www.gov.cn/test/2009-10/09/content_1434...
# 20  1969  http://www.gov.cn/test/2009-10/09/content_1434...
# 21  1970  http://www.gov.cn/test/2009-10/09/content_1434...
# 22  1971  http://www.gov.cn/test/2009-10/09/content_1434...
# 23  1972  http://www.gov.cn/test/2009-10/09/content_1434...
# 24  1973  http://www.gov.cn/test/2009-10/09/content_1434...
# 25  1974  http://www.gov.cn/test/2009-10/09/content_1434...
# 26  1975  http://www.gov.cn/test/2009-10/09/content_1434...
# 27  1976  http://www.gov.cn/test/2009-10/09/content_1434...
# 28  1977  http://www.gov.cn/test/2009-10/09/content_1434...
# 29  1978  http://www.gov.cn/test/2009-10/09/content_1434...
# 30  1979  http://www.gov.cn/test/2009-10/09/content_1434...
# 31  1980  http://www.gov.cn/test/2009-10/09/content_1434...
# 32  1981  http://www.gov.cn/test/2009-10/09/content_1434...
# 33  1982  http://www.gov.cn/test/2009-10/09/content_1434...
# 34  1983  http://www.gov.cn/test/2009-10/09/content_1434...
# 35  1984  http://www.gov.cn/test/2009-10/09/content_1434...
# 36  1985  http://www.gov.cn/test/2009-10/09/content_1434...
# 37  1986  http://www.gov.cn/test/2009-10/09/content_1434...
# 38  1987  http://www.gov.cn/test/2009-10/09/content_1434...
# 39  1988  http://www.gov.cn/test/2009-10/09/content_1434...
# 40  1989  http://www.gov.cn/test/2009-10/09/content_1434...
# 41  1990  http://www.gov.cn/test/2009-10/09/content_1434...
# 42  1991  http://www.gov.cn/test/2009-10/09/content_1434...
# 43  1992  http://www.gov.cn/test/2009-10/09/content_1434...
# 44  1993  http://www.gov.cn/test/2009-10/09/content_1434...
# 45  1994  http://www.gov.cn/test/2009-10/09/content_1434...
# 46  1995  http://www.gov.cn/test/2009-10/09/content_1434...
# 47  1996  http://www.gov.cn/test/2009-10/09/content_1434...
# 48  1997  http://www.gov.cn/test/2009-10/09/content_1434...
# 49  1998  http://www.gov.cn/test/2009-10/09/content_1434...
# 50  1999  http://www.gov.cn/test/2009-10/09/content_1434...
# 51  2000  http://www.gov.cn/test/2009-10/09/content_1434...
# 52  2001  http://www.gov.cn/test/2009-10/09/content_1434...
# 53  2002  http://www.gov.cn/test/2009-10/09/content_1434...
# 54  2003  http://www.gov.cn/test/2009-10/09/content_1434...
# 55  2004  http://www.gov.cn/test/2009-10/09/content_1434...
# 56  2005  http://www.gov.cn/test/2009-10/09/content_1434...
# 57  2006  http://www.gov.cn/test/2009-10/09/content_1434...
# 58  2008  http://www.gov.cn/test/2009-10/09/content_1434...
# 59  2009  http://www.gov.cn/test/2009-10/09/content_1434...
#
#                    name
# 0   content_1434220.htm
# 1   content_1434234.htm
# 2   content_1434235.htm
# 3   content_1434236.htm
# 4   content_1434238.htm
# 5   content_1434242.htm
# 6   content_1434243.htm
# 7   content_1434249.htm
# 8   content_1434252.htm
# 9   content_1434254.htm
# 10  content_1434258.htm
# 11  content_1434259.htm
# 12  content_1434260.htm
# 13  content_1434261.htm
# 14  content_1434262.htm
# 15  content_1434264.htm
# 16  content_1434268.htm
# 17  content_1434269.htm
# 18  content_1434277.htm
# 19  content_1434278.htm
# 20  content_1434279.htm
# 21  content_1434280.htm
# 22  content_1434281.htm
# 23  content_1434282.htm
# 24  content_1434283.htm
# 25  content_1434285.htm
# 26  content_1434286.htm
# 27  content_1434288.htm
# 28  content_1434289.htm
# 29  content_1434294.htm
# 30  content_1434297.htm
# 31  content_1434298.htm
# 32  content_1434299.htm
# 33  content_1434300.htm
# 34  content_1434317.htm
# 35  content_1434321.htm
# 36  content_1434323.htm
# 37  content_1434326.htm
# 38  content_1434327.htm
# 39  content_1434328.htm
# 40  content_1434332.htm
# 41  content_1434334.htm
# 42  content_1434362.htm
# 43  content_1434364.htm
# 44  content_1434365.htm
# 45  content_1434366.htm
# 46  content_1434367.htm
# 47  content_1434368.htm
# 48  content_1434371.htm
# 49  content_1434372.htm
# 50  content_1434373.htm
# 51  content_1434374.htm
# 52  content_1434383.htm
# 53  content_1434404.htm
# 54  content_1434405.htm
# 55  content_1434407.htm
# 56  content_1434411.htm
# 57  content_1434412.htm
# 58  content_1434430.htm
# 59  content_1434432.htm

# %%
df = raw_table.copy()

contents = df['url'].map(content_from_url)

lst = []

for j, content in tqdm(enumerate(contents), 'Parse contents'):
    soup = bs(content)
    ps = soup.find_all('font', attrs=dict(id='Zoom'))[0].find_all('p')
    lst.append([e.text for e in ps])

    if '下一页' in soup.text:
        url = df.iloc[j]['url']
        url2 = url.replace('.htm', '_2.htm')
        print('----', url, url2)
        content2 = content_from_url(url2)
        soup2 = bs(content2)
        ps2 = soup2.find_all('font', attrs=dict(id='Zoom'))[0].find_all('p')
        lst[-1] += [e.text for e in ps2]

df['events'] = lst
df['num_events'] = df['events'].map(len)

detail_table = df
detail_table.iloc[:4]
# Out:
# Parse contents: 0it [00:00, ?it/s]
# ---- http://www.gov.cn/test/2009-10/09/content_1434220.htm http://www.gov.cn/test/2009-10/09/content_1434220_2.htm
# ---- http://www.gov.cn/test/2009-10/09/content_1434234.htm http://www.gov.cn/test/2009-10/09/content_1434234_2.htm
# ---- http://www.gov.cn/test/2009-10/09/content_1434297.htm http://www.gov.cn/test/2009-10/09/content_1434297_2.htm
# ---- http://www.gov.cn/test/2009-10/09/content_1434365.htm http://www.gov.cn/test/2009-10/09/content_1434365_2.htm
#    year                                                url  \
# 0  1949  http://www.gov.cn/test/2009-10/09/content_1434...
# 1  1950  http://www.gov.cn/test/2009-10/09/content_1434...
# 2  1951  http://www.gov.cn/test/2009-10/09/content_1434...
# 3  1952  http://www.gov.cn/test/2009-10/09/content_1434...
#
#                   name                                             events  \
# 0  content_1434220.htm  [    １９４９年,     １０月１日　中华人民共和国中央人民政府成立。此前，中国人民政...
# 1  content_1434234.htm  [    １９５０年,     １月６日　北京市军事管制委员会颁发布告，宣布收回在京的外国兵...
# 2  content_1434235.htm  [    １９５１年,     ２月２３日　政务院通过《中华人民共和国劳动保险条例》，自本年...
# 3  content_1434236.htm  [    １９５２年,     １月２６日　中共中央发出《关于首先在大中城市开展“五反”斗争...
#
#    num_events
# 0          16
# 1          21
# 2           7
# 3           8

# %%
df.columns
# Out:
# Index(['year', 'url', 'name', 'events', 'num_events'], dtype='object')

# %%
df = detail_table.copy()

lst = []
drop_titles = []
for j in tqdm(df.index, 'Build long table'):
    year = df.loc[j, 'year']
    url = df.loc[j, 'url']
    name = df.loc[j, 'name']
    events = df.loc[j, 'events']

    for event in events:
        event = event.strip()
        if len(event) == 5 and '年' in event:
            drop_titles.append(event)
            continue

        lst.append(dict(
            year=year,
            date=event.split()[0],
            event=event,
            url=url,
            name=name
        ))

print('Ignore the year titles:')
print(drop_titles)

df = pd.DataFrame(lst)

long_table = df
long_table.to_csv('long_table.csv')
long_table
# Out:
# Build long table:   0%|          | 0/60 [00:00<?, ?it/s]
# Ignore the year titles:
# ['１９４９年', '１９５０年', '１９５１年', '１９５２年', '１９５３年', '１９５４年', '１９５５年', '１９５６年', '１９５７年', '１９５８年', '１９５９年', '１９６０年', '１９６１年', '１９６２年', '１９６３年', '１９６４年', '１９６５年', '１９６６年', '１９６７年', '１９６８年', '１９６９年', '１９７０年', '１９７１年', '１９７２年', '１９７３年', '１９７４年', '１９７５年', '１９７６年', '１９７７年', '１９７８年', '１９７９年', '１９８０年', '１９８１年', '１９８２年', '１９８３年', '１９８４年', '１９８５年', '１９８６年', '１９８７年', '１９８８年', '１９８９年', '１９９０年', '１９９１年', '１９９２年', '１９９３年', '１９９４年', '１９９５年', '１９９６年', '１９９７年', '１９９８年', '１９９９年', '２０００年', '２００１年', '２００２年', '２００３年', '２００４年', '２００５年', '２００６年', '２００８年', '２００９年']
#      year       date                                              event  \
# 0    1949      １０月１日  １０月１日　中华人民共和国中央人民政府成立。此前，中国人民政治协商会议第一届全体会议于９月２...
# 1    1949      １０月２日  １０月２日　苏联政府决定同新中国建立外交关系。３日，周恩来复电表示热忱欢迎，并互派大使。自１...
# 2    1949      １０月９日  １０月９日　中国人民政治协商会议第一届全国委员会第一次会议召开，选举毛泽东为政协第一届全国委...
# 3    1949     １０月１３日  １０月１３日　中国新民主主义青年团中央召开常委扩大会议，通过建立中国少年儿童队的决议。１９５...
# 4    1949     １０月２１日  １０月２１日　中央人民政府政务院宣告成立。政务院设政治法律委员会、财政经济委员会、文化教育委...
# ..    ...        ...                                                ...
# 572  2009      ８月２５日  ８月２５日　胡锦涛出席新疆维吾尔自治区干部大会并发表讲话，强调始终坚持一手抓改革发展，一手抓...
# 573  2009      ９月１４日  ９月１４日　胡锦涛等党和国家领导人会见“１００位为新中国成立作出突出贡献的英雄模范人物和１０...
# 574  2009  ９月１５日－１８日  ９月１５日－１８日　中共十七届四中全会召开，通过《中共中央关于加强和改进新形势下党的建设若干...
# 575  2009      ９月２０日  ９月２０日　胡锦涛等党和国家领导人出席庆祝中国人民政治协商会议成立６０周年大会，胡锦涛在会上...
# 576  2009  ９月２２日－２５日  ９月２２日－２５日　胡锦涛出席在纽约举行的联合国气候变化峰会、第六十四届联合国大会一般性辩论...
#
#                                                    url                 name
# 0    http://www.gov.cn/test/2009-10/09/content_1434...  content_1434220.htm
# 1    http://www.gov.cn/test/2009-10/09/content_1434...  content_1434220.htm
# 2    http://www.gov.cn/test/2009-10/09/content_1434...  content_1434220.htm
# 3    http://www.gov.cn/test/2009-10/09/content_1434...  content_1434220.htm
# 4    http://www.gov.cn/test/2009-10/09/content_1434...  content_1434220.htm
# ..                                                 ...                  ...
# 572  http://www.gov.cn/test/2009-10/09/content_1434...  content_1434432.htm
# 573  http://www.gov.cn/test/2009-10/09/content_1434...  content_1434432.htm
# 574  http://www.gov.cn/test/2009-10/09/content_1434...  content_1434432.htm
# 575  http://www.gov.cn/test/2009-10/09/content_1434...  content_1434432.htm
# 576  http://www.gov.cn/test/2009-10/09/content_1434...  content_1434432.htm
#
# [577 rows x 5 columns]

# %%
words = []

def _parse_event(se):
    idx = se.name
    year = se['year']
    sentence = se['event'].split(maxsplit=1)[1]

    for word in jieba.cut(sentence):
        if len(word.strip()) < 2:
            continue
        words.append(dict(idx=idx, year=year, word=word))

long_table.apply(_parse_event, axis=1)

words = pd.DataFrame(words)
words['pinyin'] = words['word'].map(lambda e: pinyin.get(e, format='strip'))
words.to_csv('words.csv')
words
# Out:
#        idx  year           word                                         pinyin
# 0        0  1949  中华人民共和国中央人民政府  zhonghuarenmingongheguozhongyangrenminzhengfu
# 1        0  1949             成立                                        chengli
# 2        0  1949             此前                                         ciqian
# 3        0  1949     中国人民政治协商会议            zhongguorenminzhengzhixieshanghuiyi
# 4        0  1949            第一届                                        diyijie
# ...    ...   ...            ...                                            ...
# 12147  576  2009           十国集团                                   shiguojituan
# 12148  576  2009            领导人                                     lingdaoren
# 12149  576  2009            第三次                                        disanci
# 12150  576  2009             金融                                        jinrong
# 12151  576  2009             峰会                                        fenghui
#
# [12152 rows x 4 columns]
